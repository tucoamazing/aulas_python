# %% [markdown]
# Execicio 1: Crie um programa que mostre na tela:

# %%
a = "Eu estou aprendendo Python"
print(a)
# Out:
# Eu estou aprendendo Python

# %% [markdown]
# Exercício 2
# Crie um programa que mostre:

# %%
a = "Meu nome é Maria"
b = "Eu moro em Recife"
print(a)
print(b)
# Out:
# Meu nome é Maria
# Eu moro em Recife

# %% [markdown]
# Exercício 3
# Crie duas variáveis: nome_do_aluno e idade_do_aluno.
# Depois mostre na tela algo assim:
#
# Meu nome é Ana e tenho 18 anos

# %%
nome_do_aluno = "Ana"
idade_do_aluno = 18
print(f"Meu nome é {nome_do_aluno} e tenho {idade_do_aluno} anos")
# Out:
# Meu nome é Ana e tenho 18 anos

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais. E mostre:
# Eu moro em Salvador - BA, Brasil

# %%
cidade = "Salvador"
estado = "GO"
pais = "Brasil"
print(f"Eu moro em {cidade} - {estado}, {pais}")
# Out:
# Eu moro em Salvador - GO, Brasil

# %%
entrada = input("Digite seu nome: ")
cidade = input("Qual a cidade onde você mora: ")
# Out:
# Digite seu nome:  Arthur
# Qual a cidade onde você mora:  Goiania
